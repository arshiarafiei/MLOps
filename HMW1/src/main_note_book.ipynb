# %% [markdown]
# # Note Book

# %% [markdown]
# ## Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np


data = pd.read_csv('data/sampregdata.csv')


X = data[['x1']]
y = data['y']


# Plot data points
plt.scatter(X, y, color='blue', label='data')


plt.xlabel('x1')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ## Model

# %%
import pandas as pd
from model.model_LR import LR

data = pd.read_csv('data/sampregdata.csv') 

X = data[['x1']]
y = data['y']


model_X1 = LR()


model_X1.fit(X, y)


predictions_1 = model_X1.predict(X)


print("Predictions:", predictions_1)
# Out:
# Predictions: [4.30856732 4.39989147 4.31763531 ... 4.32016439 4.36342864 4.4266198 ]

# %%
import pandas as pd
from model.model_LR import LR

data = pd.read_csv('data/sampregdata.csv') 


X = data[['x1','x2']]
y = data['y']


model_X2 = LR()


model_X2.fit(X, y)


predictions_2 = model_X2.predict(X)


print("Predictions:", predictions_2)
# Out:
# Predictions: [-0.9369307   6.30161299  3.66069212 ...  5.05975362  3.75217006
#   6.42878576]

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error


# Calculate Mean Squared Error
mse_1 = mean_squared_error(y, predictions_1)
mse_2 = mean_squared_error(y, predictions_2)
print("Mean Squared Error for 1 X:", mse_1)
print("Mean Squared Error for 2 X:", mse_2)
# Out:
# Mean Squared Error for 1 X: 114.77899751375166
# Mean Squared Error for 2 X: 76.49322242393383
